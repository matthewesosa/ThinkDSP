# %% [markdown]
# # DSP Homework 4, matriculation number: 11145118
# Generated on: 21.01.2021 at: 22:05:54 h.
# ### Please execute the next code cells to start your lab/homework!

# %%
# iPython magic command to load the matplotlib library and
# select the notebook graphics frontend
# %matplotlib inline
# import necessary functions from the thkdss library
from thkdsp import *
from dsplab import *
# import audio related functions from the audio submodule
from thkdsp.audio import play_signal, wav2dtsignal
# import some definitions and functions from numpy, the python library for Matlab-like array processing
from numpy import arange, shape, array, zeros, size, ones, isscalar

# %%
# set font for Matplotlib to 'Times New Roman' if that is available
set_mpl_font()
# set default font size for Matplotlib, change to different value if labels are too large or too small
set_mpl_fontsize(16)

# %%
# start homework
dsp_hw4_start()
# Out:
# TH Köln University of Applied Sciences
# Course:  Digital Signal Processing
# Homework 4
#
# You are about to start Homework 4 !
# Please read and follow the instructions exactly as stated!
#
# You will be asked to enter your matriculation number.
# Please make sure that you enter it correctly!
#
# Please enter your 8-digit matriculation number: 11145118
# Your matriculation number is:  11145118
# Is this correct? yes/no: yes
# Starting output to log file for Homework 4 for matriculation number: 11145118
# dsp_hw4_11145118.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : dsp_hw4_11145118.log
# Mode           : append
# Output logging : True
# Raw input log  : True
# Timestamping   : True
# State          : active
# Info: 8072044517
# Homework 4 for matriculation number 11145118 started at: 2021-01-21 22:08:06.137237

# %% [markdown]
# ### Enter as many code cells as you need below!
# ### Note: Your notebook needs to be modular enough, i.e. it has to consist of enough code cells!
# ### Otherwise, your submission will be considered as not sufficient!

# %%
import numpy as np
from numpy import poly, array
import matplotlib.pyplot as plt
from thkdsp.ztransform import residue, residuez, zplane
from scipy.signal import lfilter

# %%
n = lrange(-5, 20)

# %%
sn = np.sin(2*np.pi*n/4) * step(n)

# %%
zn1 = np.complex(0, 1)

# %%
zn2 = np.complex(0, -1)

# %%
zp1 = np.complex(-1/2, 1/2)

# %%
zp2 = np.complex(-1/2, -1/2)

# %%
a = 5/4 * poly([zn1, zn2])

# %%
b = poly([zp1, zp2])

# %%
fig, ax = zplane(a, b) #pole-zero plot

# %%
r, p, k = residue(a, b)

# %%
print('r = '+str(r)+', p = '+str(p)+', k = '+str(k))
# Out:
# r = [-0.625-1.25j -0.625+1.25j], p = [-0.5+0.5j -0.5-0.5j], k = [1.25]

# %%
gn = lfilter(a, b, sn)

# %%
fig1, ax1 = plot_signal(n, sn, xlabel = "n", ylabel = "s[n]", color = "r") #input signal

# %%
fig2, ax2 = plot_signal(n, gn, xlabel = "n", ylabel = "g[n]", color = "r") #output signal

# %% [raw]
# 5.8 (c) done

# %%
a = np.array([1, -2, 1])

# %%
b = np.array([4, 0, 0])

# %%
fig, ax = zplane(a, b)

# %%
r, p, k = residue(a, b)

# %%
print('r = '+str(r)+', p = '+str(p)+', k = '+str(k))
# Out:
# r = [-0.5   0.25], p = [0. 0.], k = [0.25]

# %%
sn = (2*(0.9)**n) * step(n)

# %%
gn = lfilter(a, b, sn)

# %%
fig1, ax1 = plot_signal(n, sn, xlabel = "n", ylabel = "g[n]", color = "r") #input signal

# %%
fig2, ax2 = plot_signal(n, gn, xlabel = "n", ylabel = "g[n]", color = "r")

# %% [raw]
# 5.9(a) done

# %%
a = np.array([1, -0.5, 0])

# %%
b = np.array([1, 0.5, -0.25])

# %%
fig, ax = zplane(a, b)

# %%
r, p, k = residue(a, b)

# %%
print('r = '+str(r)+', p = '+str(p)+', k = '+str(k))
# Out:
# r = [-0.9472136 -0.0527864], p = [-0.80901699  0.30901699], k = [1.]

# %%
gn = lfilter(a, b, sn)

# %%
fig1, ax1 = plot_signal(n, sn, xlabel = "n", ylabel = "s[n]", color = "r")

# %%
fig2, ax2 = plot_signal(n, gn, xlabel = "n", ylabel = "g[n]", color = "r")

# %% [raw]
# 5.9(b) done

# %%
a = np.array([2, 0])

# %%
b = np.array([1, 0.5])

# %%
fig, ax = zplane(a, b)

# %%
r, p, k = residue(a, b)

# %%
print('r = '+str(r)+', p = '+str(p)+', k = '+str(k))
# Out:
# r = [-1.], p = [-0.5], k = [2.]

# %%
gn = lfilter(a, b, sn)

# %%
fig1, ax1 = plot_signal(n, sn, xlabel = "n", ylabel = "s[n]", color = "r")

# %%
fig2, ax2 = plot_signal(n, gn, xlabel = "n", ylabel = "g[n]", color = "r")

# %% [raw]
# 5.9(c) done

# %%
a = np.array([1.2, 0.6, -1])

# %%
b = np.array([1, -0.4, -0.45])

# %%
fig, ax = zplane(a, b)

# %%
r, p, k = residue(a, b)

# %%
print('r = '+str(r)+', p = '+str(p)+', k = '+str(k))
# Out:
# r = [0.36571429 0.71428571], p = [ 0.9 -0.5], k = [1.2]

# %%
gn = lfilter(a, b, sn)

# %%
fig1, ax1 = plot_signal(n, sn, xlabel = "n", ylabel = "s[n]", color = "r")

# %%
fig2, ax2 = plot_signal(n, gn, xlabel = "n", ylabel = "g[n]", color = "r")

# %% [raw]
# 5.9(d) done

# %%
a = np.array([]) #empty array for coefficient matrix, s[n]

# %%
b = np.array([1]) #first element (0th element) will be 1, g[n]

# %%
#for s[n] coefficient
for k1 in range(0, 5):
    v1 = (4/3)**k1
    a = np.append(a, v1)

# %%
#for g[n] coefficient
for k2 in range(1, 5):
    v2 = (3/4)**k2
    b = np.append(b, v2)

# %%
print('a = '+str(a)+'\nb = '+str(b))
# Out:
# a = [1.         1.33333333 1.77777778 2.37037037 3.16049383]
# b = [1.         0.75       0.5625     0.421875   0.31640625]

# %%
fig, ax = zplane(a, b)

# %%
r, p, k = residue(a, b)

# %%
print('r = '+str(r)+'\np = '+str(p)+'\nk = '+str(k))
# Out:
# r = [-1.06451386-1.31100513j -1.06451386+1.31100513j  1.35618053-1.18717595j
#   1.35618053+1.18717595j]
# p = [ 0.23176275+0.71329239j  0.23176275-0.71329239j -0.60676275+0.44083894j
#  -0.60676275-0.44083894j]
# k = [1.]

# %%
gn = lfilter(a, b, sn)

# %%
fig1, ax1 = plot_signal(n, sn, xlabel = "n", ylabel = "s[n]", color = "r")

# %%
fig2, ax2 = plot_signal(n, gn, xlabel = "n", ylabel = "g[n]", color = "r")

# %% [raw]
# 5.9(e) done

# %% [markdown]
# ### When you run the command in the next code cell, the lab/homework will be finished!
# ### Execute the next code cell only if you really want to finish this lab/homework!
# ### This code cell should be your last code cell!

# %%
# finish homework
dsp_hw4_finish()
# Out:
# You are about to finish Homework 4 !
# This will finish output to the log file, such that you should not enter any command after finishing!
#
# Thus, proceed only if you are sure that you are really finished!!
# Do you really want to finish? yes/no: yes
# Finishing Homework 4 for matriculation number 11145118
# Homework 4  finished at: 2021-01-22 01:53:33.203849
# Finished after: 3:45:27.066629
# Info:  8072044517
# Congratulations! You have just finished Homework 4 !
#
# In your current working directory you will find the following Log file:
#
# Log file:  dsp_hw4_11145118.log
#
# Please save this iPython notebook one more time!
#
# Please upload both files to the ILIAS server:
# If this is a homework, use the 'Homework' folder of the ILIAS DSP internet pages!
# If this is a lab, use the 'Lab' folder of the ILIAS DSP internet pages!
#
# In either case you will be notified on the status of your submission via email.
#
# So stay tuned!
# Harald Elders-Boll

# %% [markdown]
# ### Please save this notebook one more time!
