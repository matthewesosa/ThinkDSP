# %% [markdown]
# # DSP Homework 2, matriculation number: 11144732
# Generated on: 18.11.2021 at: 16:15:46 h.
# ### Please execute the next code cells to start your lab/homework!

# %%
# iPython magic command to load the matplotlib library and
# select the notebook graphics frontend
# %matplotlib inline
# import necessary functions from the thkdss library
from thkdsp import *
from dsplab import *
# import audio related functions from the audio submodule
from thkdsp.audio import play_signal, wav2dtsignal
# import some definitions and functions from numpy, the python library for Matlab-like array processing
from numpy import arange, shape, array, zeros, size, ones, isscalar

# %%
# set font for Matplotlib to 'Times New Roman' if that is available
set_mpl_font()
# set default font size for Matplotlib, change to different value if labels are too large or too small
set_mpl_fontsize(16)

# %%
# start homework
dsp_hw2_start()
# Out:
# TH Köln University of Applied Sciences
# Course:  Digital Signal Processing
# Homework 2
#
# You are about to start Homework 2 !
# Please read and follow the instructions exactly as stated!
#
# You will be asked to enter your matriculation number.
# Please make sure that you enter it correctly!
#
# Please enter your 8-digit matriculation number: 11144732
# Your matriculation number is:  11144732
# Is this correct? yes/no: yes
# Starting output to log file for Homework 2 for matriculation number: 11144732
# dsp_hw2_11144732.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : dsp_hw2_11144732.log
# Mode           : append
# Output logging : True
# Raw input log  : True
# Timestamping   : True
# State          : active
# Info: 2562463468
# Homework 2 for matriculation number 11144732 continued at: 2021-11-19 16:37:32.350956

# %% [markdown]
# ### Enter as many code cells as you need below!
# ### Note: Your notebook needs to be modular enough, i.e. it has to consist of enough code cells!
# ### Otherwise, your submission will be considered as not sufficient!

# %%
from thkdsp import *
from thkdsp.interpolation import ideal_interpolation
from math import *
from scipy.interpolate import interp1d
from numpy import *

# %% [markdown]
# ### Problem 3.4 (Numpy)
# ### Consider an analog signal s(t) = cos(2π10t),0 ≤ t ≤ 1. It is sampled at T = 0.01,0.05, and 0.1 sec intervals to obtain s[n].

# %% [markdown]
# ### a) For each T plot s[n].

# %%
T=0.01
n= lrange(0,1,(1/T))
s_n = cos(2*pi*10*n)
plot_signal(n,s_n,'n','s')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ n \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
T= 0.05
n = lrange(0,1,(1/T))
s_n = cos(2*pi*10*n)
plot_signal(n,s_n,'n','s')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ n \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
T=0.1
n= lrange(0,1,(1/T))
s_n = cos(2*pi*10*n)
plot_signal(n,s_n,'n','s')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ n \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %% [markdown]
# ### b) Reconstruct the analog signal sr(t) from the samples s[n] using ideal interpolation (Use ∆t = 0.001) and determine the frequency in sr(t) from your plot. (Ignore the end effects.)

# %%
dt = 0.001

# %%
T=0.01
t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T)) 
s_n = cos(2*pi*10*n)
s_r = ideal_interpolation(n, s_n, t)
plot_signal(t, s_r, 't', 'sr')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ sr(t) \\rightarrow$'>)

# %%
n
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
T = 0.05
t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T)) 
s_n = cos(2*pi*10*n)
s_r = ideal_interpolation(n, s_n, t)
plot_signal(t, s_r, 't', 'sr')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ sr(t) \\rightarrow$'>)

# %%
T = 0.1
t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T)) 
s_n = cos(2*pi*10*n)
s_r = ideal_interpolation(n, s_n, t)
plot_signal(t, s_r, 't', 'sr')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ sr(t) \\rightarrow$'>)

# %% [markdown]
# ### c) Reconstruct the analog signal ssp(t) from the samples s[n] using the cubic spline interpolation and determine the frequency in ssp(t) from your plot. (Again ignore the end effects.)

# %%
dt = 0.001

# %%
T=0.01
def s(t):
    return cos(2*pi*10*t)

t = lrange(0, 1, (1/dt))

# sampling period and points
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
plot_signal(t, s_sp, 't', 's_sp' )
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s_sp(t) \\rightarrow$'>)

# %%
T=0.05
def s(t):
    return cos(2*pi*10*t)

t = lrange(0, 1, (1/dt))

# sampling period and points
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
plot_signal(t, s_sp,'t', 's_sp')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s_sp(t) \\rightarrow$'>)

# %%
T=0.1
def s(t):
    return cos(2*pi*10*t)

t = lrange(0, 1, (1/dt))

# sampling period and points
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
plot_signal(t, s_sp,'t', 's_sp')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s_sp(t) \\rightarrow$'>)

# %% [markdown]
# ### d) Comments on your results.

# %% [markdown]
# ### Problem 3.5 (Numpy)
# ### Consider the analog signal s(t) = sin(2π10t +θ),0 ≤ t ≤ 1. It is sampled at T = 0.05 sec intervals to obtain s[n]. Let θ = 0, π/6, π/4, π/3, π/2. For each of these θ values, perform the following:

# %% [markdown]
# ### a) Plot s(t) and superimpose s[n] on it using the plot_signal or the stem function.

# %%
T = 0.05

# %%
θ = 0

t = lrange(0, 1, (1/T))
n = lrange(0, 1, (1/T))
s_t = sin((2*pi*10*t) + θ)
s_n = sin((2*pi*10*n) + θ)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_t, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
θ = pi/6

t = lrange(0, 1, (1/T))
n = lrange(0, 1, (1/T))
s_t = sin((2*pi*10*t) + θ)
s_n = sin((2*pi*10*n) + θ)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_t, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
θ = pi/4

t = lrange(0, 1, (1/T))
n = lrange(0, 1, (1/T))
s_t = sin((2*pi*10*t) + θ)
s_n = sin((2*pi*10*n) + θ)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_t, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
θ = pi/3

t = lrange(0, 1, (1/T))
n = lrange(0, 1, (1/T))
s_t = sin((2*pi*10*t) + θ)
s_n = sin((2*pi*10*n) + θ)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_t, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
θ = pi/2

t = lrange(0, 1, (1/T))
n = lrange(0, 1, (1/T))
s_t = sin((2*pi*10*t) + θ)
s_n = sin((2*pi*10*n) + θ)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_t, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %% [markdown]
# ### b) Reconstruct the analog signal sr(t) from the samples s[n] using ideal interpolation (Use ∆t = 0.001) and superimpose s[n] on it.

# %%
dt = 0.001
T = 0.05

# %%
Ɵ = 0

t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T))
s_n = sin((2*pi*10*n) + Ɵ)
s_r = ideal_interpolation(n, s_n, t)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_r, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/6

t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T))
s_n = sin((2*pi*10*n) + Ɵ)
s_r = ideal_interpolation(n, s_n, t)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_r, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/4

t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T))
s_n = sin((2*pi*10*n) + Ɵ)
s_r = ideal_interpolation(n, s_n, t)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_r, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/3

t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T))
s_n = sin((2*pi*10*n) + Ɵ)
s_r = ideal_interpolation(n, s_n, t)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_r, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/2

t = lrange(0, 1, (1/dt))
n = lrange(0, 1, (1/T))
s_n = sin((2*pi*10*n) + Ɵ)
s_r = ideal_interpolation(n, s_n, t)
fig, ax = plot_signal(n, s_n, 'n', 's')
plot_signal(t, s_r, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %% [markdown]
# ### c) Reconstruct the analog signal ssp(t) from the samples s[n] using the cubic spline interpolation and superimpose s[n] on it.

# %%
T=0.05
dt = 0.001

# %%
Ɵ = 0

def s(t):
    return sin((2*pi*10*t) + Ɵ)
t = lrange(0, 1, (1/dt))

# sampling period and points 
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
fig, ax = plot_signal(nT, s_n, 'n', 's')
plot_signal(t, s_sp, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/6

def s(t):
    return sin((2*pi*10*t) + Ɵ)
t = lrange(0, 1, (1/dt))

# sampling period and points 
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
fig, ax = plot_signal(nT, s_n, 'n', 's')
plot_signal(t, s_sp, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/4

def s(t):
    return sin((2*pi*10*t) + Ɵ)
t = lrange(0, 1, (1/dt))

# sampling period and points 
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
fig, ax = plot_signal(nT, s_n, 'n', 's')
plot_signal(t, s_sp, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/3

def s(t):
    return sin((2*pi*10*t) + Ɵ)
t = lrange(0, 1, (1/dt))

# sampling period and points 
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
fig, ax = plot_signal(nT, s_n, 'n', 's')
plot_signal(t, s_sp, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %%
Ɵ = pi/2

def s(t):
    return sin((2*pi*10*t) + Ɵ)
t = lrange(0, 1, (1/dt))

# sampling period and points 
tmax = 1
r = 1/T
nmax = int(tmax/T)
n = lrange(-nmax, nmax)

nT = n*T
s_n = s(nT)
spline = interp1d(nT, s_n, kind='cubic')
s_sp = spline(t)
fig, ax = plot_signal(nT, s_n, 'n', 's')
plot_signal(t, s_sp, figure=fig, axes=ax)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ s[n] \\rightarrow$'>)

# %% [markdown]
# ### d) You should observe that the resultant reconstruction in each case has the correct frequency but a different amplitude. Explain this observation. Comment on the role of phase of s(t) on sampling and reconstruction of signals.

# %% [markdown]
# ### When you run the command in the next code cell, the lab/homework will be finished!
# ### Execute the next code cell only if you really want to finish this lab/homework!
# ### This code cell should be your last code cell!

# %%
# finish homework
#dsp_hw2_finish()

# %% [markdown]
# ### Please save this notebook one more time!
