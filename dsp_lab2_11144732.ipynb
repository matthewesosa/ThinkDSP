# %% [markdown]
# # DSP Lab 2: Stochastic Processes, matriculation number: 11144732
# Generated on: 06.01.2022 at: 12:24:11 h.
# ### Please execute the next code cells to start your lab/homework!

# %%
# iPython magic command to load the matplotlib library and
# select the notebook graphics frontend
# %matplotlib inline
# import necessary functions from the thkdss library
from thkdsp import *
from dsplab import *
# import audio related functions from the audio submodule
from thkdsp.audio import play_signal, wav2dtsignal
# import some definitions and functions from numpy, the python library for Matlab-like array processing
from numpy import arange, shape, array, zeros, size, ones, isscalar

# %%
# set font for Matplotlib to 'Times New Roman' if that is available
set_mpl_font()
# set default font size for Matplotlib, change to different value if labels are too large or too small
set_mpl_fontsize(16)

# %%
# start homework
dsp_lab2_start()
# Out:
# TH Köln University of Applied Sciences
# Course:  Digital Signal Processing
# Lab 2: Stochastic Processes
#
# You are about to start Lab 2: Stochastic Processes !
# Please read and follow the instructions exactly as stated!
#
# You will be asked to enter your matriculation number.
# Please make sure that you enter it correctly!
#
# Please enter your 8-digit matriculation number: 11144732
# Your matriculation number is:  11144732
# Is this correct? yes/no: yes
# Starting output to log file for Lab 2: Stochastic Processes for matriculation number: 11144732
# dsp_lab2_11144732.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : dsp_lab2_11144732.log
# Mode           : append
# Output logging : True
# Raw input log  : True
# Timestamping   : True
# State          : active
# Info: 2562463468
# Lab 2: Stochastic Processes for matriculation number 11144732 continued at: 2022-01-09 03:47:25.600777

# %% [markdown]
# ### Enter as many code cells as you need below!
# ### Note: Your notebook needs to be modular enough, i.e. it has to consist of enough code cells!
# ### Otherwise, your submission will be considered as not sufficient!

# %%
from dsplab.lab2 import *
import pandas as pd
import numpy as np

# %% [markdown]
# ### Sample functions of different stochastic processes :

# %%
# Sample function and Segment duration T in seconds

T = 2
M = 10000

# %%
t1, s1 = urp(M, T, 1)

# %%
plot_ensemble(t1, s1, K=4, domainname='t', signalname='s1')

# %%
t2, s2 = urp(M, T, 2)

# %%
plot_ensemble(t2, s2, K=4, domainname='t', signalname='s2')

# %%
t3, s3 = urp(M, T, 3)

# %%
plot_ensemble(t3, s3, K=4, domainname='t', signalname='s3')

# %%
t4, s4 = urp(M, T, 4)

# %%
plot_ensemble(t4, s4, K=4, domainname='t', signalname='s4')

# %%
t5, s5 = urp(M, T, 5)

# %%
plot_ensemble(t5, s5, K=4, domainname='t', signalname='s5')

# %% [markdown]
# ### Testing for stationarity :

# %%
fig, ax = plot_signal(t1, np.mean(s1, 0), plotaxes=False, label="1")

# %%
fig, ax = plot_signal(t2, np.mean(s2, 0), plotaxes=False, figure=fig, axes=ax, label="2")

# %%
fig, ax = plot_signal(t3, np.mean(s3, 0), plotaxes=False, figure=fig, axes=ax, label="3")

# %%
fig, ax = plot_signal(t4, np.mean(s4, 0), plotaxes=False, figure=fig, axes=ax, label="4")

# %%
fig, ax = plot_signal(t5, np.mean(s5, 0), plotaxes=False, figure=fig, axes=ax, label="5")

# %%
ax.axis("auto")
ax.legend()

# %%
fig

# %% [markdown]
# Number of the non-stationary random process: 4

# %% [markdown]
# ### Autocorrelation function of stationary random processes :

# %%
tau1, varphi1=acf_ensemble(t1, s1)

# %%
plot_acf(tau1, varphi1)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
# Maximum value of the ACF
max_1 = np.max(varphi1)
max_1
# Out:
# 26.839652378601937

# %%
# Power of Process 1 (Ps1). 

# The Power can be obtained by observing the plot for the ACF vaue at tau = 0 
# and by using 'np.where()' Function to obtain the corresponding value of the ACF at tau = 0

index_1 = np.where(tau1 == 0)
index_1
# Out:
# (array([199], dtype=int64),)

# %%
Ps1 = varphi1[199]
Ps1
# Out:
# 26.839652378601937

# %%
tau2, varphi2=acf_ensemble(t2, s2)

# %%
plot_acf(tau2, varphi2)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
# Maximum value of the ACF
max_2 = np.max(varphi2)
max_2
# Out:
# 19.82740005752647

# %%
# Power of Process 2 (Ps2). 

index_2 = np.where(tau2 == 0)
index_2
# Out:
# (array([199], dtype=int64),)

# %%
Ps2 = varphi2[199]
Ps2
# Out:
# 19.82740005752647

# %%
tau3, varphi3=acf_ensemble(t3, s3)

# %%
plot_acf(tau3, varphi3)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
# Maximum value of the ACF
max_3 = np.max(varphi3)
max_3
# Out:
# 27.831099338368954

# %%
# Power of Process 3 (Ps3). 

index_3 = np.where(tau3 == 0)
index_2
# Out:
# (array([199], dtype=int64),)

# %%
Ps3 = varphi3[199]
Ps3
# Out:
# 27.831099338368954

# %%
tau5, varphi5=acf_ensemble(t5, s5)

# %%
plot_acf(tau5, varphi5)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
# Maximum value of the ACF
max_5 = np.max(varphi5)
max_5
# Out:
# 18.75079219627051

# %%
# Power of Process 5 (Ps5). 

index_5 = np.where(tau5 == 0)
index_5
# Out:
# (array([199], dtype=int64),)

# %%
Ps5 = varphi5[199]
Ps5
# Out:
# 18.75079219627051

# %% [markdown]
# ### Table 1: Properties of the unknown random processes:

# %%
dict1 = { 'Property' : ['Stationary[Yes/No]', 'Power Ps', 'Harmonic Component[Yes/No]', 'Spectral Characteristics'],
        'URP1' : ['Yes', Ps1, 'Yes', 'HPN'],
        'URP2' : ['Yes', Ps2, 'No', 'LPN'],
        'URP3' : ['Yes', Ps3, 'Yes', 'HPN'],
        'URP4' : ['No', '-', '-', '-'],
        'URP5' : ['Yes', Ps5, 'No', 'HPN']
    }

# %%
table1 = pd.DataFrame(dict1)
table1.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_b6604e83_757d_11ec_a4c9_c4d98744e9e4" ><thead>    <tr>        <th class="col_heading level0 col0" >Property</th>        <th class="col_heading level0 col1" >URP1</th>        <th class="col_heading level0 col2" >URP2</th>        <th class="col_heading level0 col3" >URP3</th>        <th class="col_heading level0 col4" >URP4</th>        <th class="col_heading level0 col5" >URP5</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b6604e83_757d_11ec_a4c9_c4d98744e9e4row0_col0" class="data row0 col0" >Stationary[Yes/No]</td>
#                         <td id="T_b6604e83_757d_11ec_a4c9_c4d98744e9e4row0_col1" class="data row0 col1" >Yes</td>
#                         <td id="T_b6604e83_757d_11ec_a4c9_c4d98744e9e4row0_col2" class="data row0 col2" >Yes</td>
#                         <td id="T_b6604e83_757d_11ec_a4c9_c4d98744e9e4row0_col3" class="data row0 col3" >Yes</td>
# ...

# %% [markdown]
# ### Estimation of the power density spectrum :

# %%
# Sample function and Segment duration T in seconds

T = 10
M = 1000

# %%
t1, s1 = urp(M, T, 1)

# %%
plot_ensemble_tf(t1, s1)

# %%
t2, s2 = urp(M, T, 2)

# %%
plot_ensemble_tf(t2, s2)

# %%
t3, s3 = urp(M, T, 3)

# %%
plot_ensemble_tf(t3, s3)

# %%
t3, s3 = urp(M, T, 5)

# %%
plot_ensemble_tf(t5, s5)

# %%
f1, phi1 = pds_ensemble(t1, s1)
plot_pds(f1, phi1)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
f2, phi2 = pds_ensemble(t2, s2)
plot_pds(f2, phi2)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
f3, phi3 = pds_ensemble(t3, s3)
plot_pds(f3, phi3)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
f5, phi5 = pds_ensemble(t5, s5)
plot_pds(f5, phi5)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %% [markdown]
# ### Discrete-time white noise :

# %%
# Duration T in seconds  and Sampling rate r

T = 10
r = 48000

# %%
t_s, s = wgn(1/r, T, 1, r)

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin=0, xmax=0.05)

# %%
tau_s, varphi_ss = acf_time(t_s, s, 0.05)

# %%
acf_fig, acf_ax = plot_acf(tau_s, varphi_ss)

# %%
f_s, PHI_ss = pds_time(t_s, s)

# %%
pds_fig, pds_ax = plot_pds(f_s,PHI_ss)

# %%
play_signal(t_s, s)

# %% [markdown]
# ### Moving average of white noise :

# %%
# Signal duration T_d and Sampling rate r

T_d = 0.001
r = 48000

# %%
t_d, d = gen_dirac(T_d, r)

# %%
# Impulse respone


t_h, h = moving_average(t_d, d, 1/r)

# %%
# Plot of the impulse response

plot_signal(t_h, h, ylabel="h")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ t \\rightarrow$', ylabel='$ h(t) \\rightarrow$'>)

# %%
# Generating a sample function of the output process
t_g, g = moving_average(t_s, s, 1.0/4800.0)

# %%
# Plot of the white noise input process and the filtered noise output process 

signal_fig, signal_ax = plot_signal(t_s, s, xmin=0, xmax=0.05, plotaxes=False)
plot_signal(t_g, g, xmax=0.05, figure=signal_fig, axes=signal_ax, color="r")
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %% [markdown]
# ##### There is one obvious difference between the input and the output process :
#
# The ouput process has a reduced amplitude (reduced average power); it is not changing as fast as the input process because the Moving Average operation acts like a simple low pass filter that reduces the contribution of higher frequencies.

# %%
# Zoom in a bit moreto spot a second less obvious difference:


signal_fig, signal_ax = plot_signal(t_s, s, xmin=0.01, xmax=0.015, plotaxes=False)
plot_signal(t_g, g, xmin=0.01, xmax=0.015, figure=signal_fig, axes=signal_ax,color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %% [markdown]
# ###### Comment on the second difference between the input and the output process:
#
# Some higher frequencies are still present and visible as little spikes in the output process.

# %%
#  Estimating the autocorrelation function ϕgg(τ) of the output process using acf_time within the range −0.001s ≤ τ ≤ 0.001s:
    
tau_g, varphi_gg = acf_time(t_g, g, 0.001)

# %%
# Plot of the autocorrelation function

plot_acf(tau_g, varphi_gg, xmin=-0.001, xmax=0.001)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
#  Estimate the power density spectrum

f_g, PHI_gg = pds_time(t_g, g)

# %%
# Plot of the power density spectrum 

pds_fig, pds_ax = plot_pds(f_s, PHI_ss)
plot_pds(f_g, PHI_gg, figure=pds_fig, axes=pds_ax, color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
play_signal(t_g, g)

# %%
t_ma = t_g
g_ma = g

# %% [markdown]
# ### Ideal lowpass with discrete-time white noise input :

# %%
# The impulse response of ideal lowpass filter :

T_d = 0.01
r = 48000

# %%
t_d, d = gen_dirac(T_d, r)

# %%
# f_c is the cut-off frequency in Hz for the ideal lowpass filter.

f_c=4800

t_h, h = low_pass(t_d, d, f_c)

# %%
# Plot the impulse response h(t)

plot_signal(t_h, h)
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %%
# Investigating the output process if white noise is applied to the input of the ideal lowpass filter:

t_g, g = low_pass(t_s, s, f_c)

# %%
# Plot the white noise input process and the filtered noise output process :

signal_fig, signal_ax = plot_signal(t_s, s, xmin=0, xmax=0.05, plotaxes=False)
plot_signal(t_g, g, xmax=0.05, figure=signal_fig, axes=signal_ax, color="r")
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %% [markdown]
# #####  There is one obvious difference between the input and the output process (neglecting the fact that the filtered noise starts later):
#
#
# The ouput process has a reduced amplitude (reduced average power); it is not changing as fast as the input process because the Ideal Low pass filter has reduced the contribution of higher frequencies.

# %%
# Zoom in a bit moreto spot a second less obvious difference:

signal_fig, signal_ax = plot_signal(t_s, s, xmin=0.01, xmax=0.015, plotaxes=False)
plot_signal(t_g, g, xmin=0.01, xmax=0.015, figure=signal_fig, axes=signal_ax,color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:xlabel='$ t \\rightarrow$'>)

# %% [markdown]
# ##### Comment on the second difference between the input and the output process:
#
# Now, it is more visible that we have used a better filter; the output process is smooth, because we don't have higher frequencies than the cut off frequency f_c.

# %%
# Estimate the autocorrelation function of the output process using acf_time within the range −0.001s ≤ τ ≤ 0.001s:

tau_g, varphi_gg = acf_time(t_g, g, 0.001)

# %%
# Plot of the autocorrelation function

plot_acf(tau_g, varphi_gg, xmin=-0.001, xmax=0.001)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ \\tau \\rightarrow$', ylabel='$\\varphi_{ss}(\\tau) \\rightarrow$'>)

# %%
# Estimating the power density spectrum Φgg(f) of the output process using pds_time:
    
f_g, PHI_gg = pds_time(t_g, g)

# %%
# Plot the power density spectrum Φgg(f) using pds_time : 

pds_fig, pds_ax = plot_pds(f_s, PHI_ss)
plot_pds(f_g, PHI_gg, figure=pds_fig, axes=pds_ax, color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='$ f \\rightarrow$', ylabel='$ \\Phi_{ss}(f) \\rightarrow$'>)

# %%
play_signal(t_g, g)

# %%
# Comparing the sound of the different noise processes again:

# %%
# White noise:

play_signal(t_s, s)

# %%
# Moving average:

play_signal(t_ma, g_ma)

# %%
# Ideal lowpass:

play_signal(t_g, g)

# %% [markdown]
# ### When you run the command in the next code cell, the lab/homework will be finished!
# ### Execute the next code cell only if you really want to finish this lab/homework!
# ### This code cell should be your last code cell!

# %%
# finish homework
dsp_lab2_finish()
# Out:
# You are about to finish Lab 2: Stochastic Processes !
# This will finish output to the log file, such that you should not enter any command after finishing!
#
# Thus, proceed only if you are sure that you are really finished!!
# Do you really want to finish? yes/no: yes
# Finishing Lab 2: Stochastic Processes for matriculation number 11144732
# Lab 2: Stochastic Processes  finished at: 2022-01-14 22:08:41.583557
# Finished after: 5 days, 18:21:15.982780
# Info:  2562463468
# Congratulations! You have just finished Lab 2: Stochastic Processes !
#
# In your current working directory you will find the following Log file:
#
# Log file:  dsp_lab2_11144732.log
#
# Please save this iPython notebook one more time!
#
# Please upload both files to the ILIAS server:
# If this is a homework, use the 'Homework' folder of the ILIAS DSP internet pages!
# If this is a lab, use the 'Lab' folder of the ILIAS DSP internet pages!
#
# ...

# %% [markdown]
# ### Please save this notebook one more time!
