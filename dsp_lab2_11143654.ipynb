# %% [markdown]
# # DSP Lab 2: Stochastic Processes, matriculation number: 11143654
# Generated on: 04.02.2021 at: 14:56:42 h.
# ### Please execute the next code cells to start your lab/homework!

# %%
# iPython magic command to load the matplotlib library and
# select the notebook graphics frontend
# %matplotlib inline
# import necessary functions from the thkdss library
from thkdsp import *
from dsplab import *
# import audio related functions from the audio submodule
from thkdsp.audio import play_signal, wav2dtsignal
# import some definitions and functions from numpy, the python library for Matlab-like array processing
from numpy import arange, shape, array, zeros, size, ones, isscalar

# %%
# set font for Matplotlib to 'Times New Roman' if that is available
set_mpl_font()
# set default font size for Matplotlib, change to different value if labels are too large or too small
set_mpl_fontsize(16)

# %%
# start homework
dsp_lab2_start()
# Out:
# TH Köln University of Applied Sciences
# Course:  Digital Signal Processing
# Lab 2: Stochastic Processes
#
# You are about to start Lab 2: Stochastic Processes !
# Please read and follow the instructions exactly as stated!
#
# You will be asked to enter your matriculation number.
# Please make sure that you enter it correctly!
#
# Please enter your 8-digit matriculation number: 11143654
# Your matriculation number is:  11143654
# Is this correct? yes/no: yes
# Starting output to log file for Lab 2: Stochastic Processes for matriculation number: 11143654
# dsp_lab2_11143654.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : dsp_lab2_11143654.log
# Mode           : append
# Output logging : True
# Raw input log  : True
# Timestamping   : True
# State          : active
# Info: 5400436791
# Lab 2: Stochastic Processes for matriculation number 11143654 started at: 2021-02-04 14:57:56.864183

# %% [markdown]
# ### Enter as many code cells as you need below!
# ### Note: Your notebook needs to be modular enough, i.e. it has to consist of enough code cells!
# ### Otherwise, your submission will be considered as not sufficient!

# %%
from dsplab.lab2 import *

# %%
t1, s1 = urp(10000, 2, 1)

# %%
t2, s2 = urp(10000, 2, 2)

# %%
t3, s3 = urp(10000, 2, 3)

# %%
t4, s4 = urp(10000, 2, 4)

# %%
t5, s5 = urp(10000, 2, 5)

# %% [markdown]
# Using plot_ensemble to plot the first four sample functions for each random process.

# %%
plot_ensemble(t1, s1)

# %%
plot_ensemble(t2, s2)

# %%
plot_ensemble(t3, s3)

# %%
plot_ensemble(t4, s4)

# %%
plot_ensemble(t5, s5)

# %%
import numpy as np

# %%
fig, ax = plot_signal(t1, np.mean(s1, 0), plotaxes=False, label="1")

# %%
fig, ax = plot_signal(t2, np.mean(s2, 0), plotaxes=False, figure=fig, axes=ax, label="2")

# %%
fig, ax = plot_signal(t3, np.mean(s3, 0), plotaxes=False, figure=fig, axes=ax, label="3")

# %%
fig, ax = plot_signal(t4, np.mean(s4, 0), plotaxes=False, figure=fig, axes=ax, label="4")

# %%
fig, ax = plot_signal(t5, np.mean(s5, 0), plotaxes=False, figure=fig, axes=ax, label="5")

# %%
ax.axis("auto")
ax.legend()

# %%
fig

# %%
tau2, varphi2=acf_ensemble(t2, s2)

# %%
plot_acf(tau2, varphi2)
max(varphi2)
# Out:
# 18.43048812909502

# %%
tau3, varphi3=acf_ensemble(t3, s3)

# %%
plot_acf(tau3, varphi3)
max(varphi3)
# Out:
# 26.557733924556466

# %%
tau4, varphi4=acf_ensemble(t4, s4)

# %%
plot_acf(tau4, varphi4)
max(varphi4)
# Out:
# 19.95311385302558

# %%
tau5, varphi5=acf_ensemble(t5, s5)

# %%
plot_acf(tau5, varphi5)
max(varphi5)
# Out:
# 27.401085213289015

# %% [markdown]
# Estimation of the power density spectrum

# %%
t2, s2, = urp(1000, 10, 2)

# %%
plot_ensemble_tf(t2, s2)
f, phi = pds_ensemble(t2, s2)
plot_pds(f, phi)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f5a98430>)

# %%
t3, s3 = urp(1000, 10, 3)

# %%
plot_ensemble_tf(t3, s3)
f, phi = pds_ensemble(t3, s3)
plot_pds(f, phi)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f5a54640>)

# %%
t4, s4 = urp(1000, 10, 4)

# %%
plot_ensemble_tf(t4, s4)
f, phi = pds_ensemble(t4, s4)
plot_pds(f, phi)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f451cd30>)

# %%
t5, s5 = urp(1000, 10, 5)

# %%
plot_ensemble_tf(t5, s5)
f, phi = pds_ensemble(t5, s5)
plot_pds(f, phi)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f70a25b0>)

# %%
r = 48000

# %%
t_s, s = wgn(1/r, 10, 1, r)

# %%
#Plot the generated sample function using plot_signal

signal_fig, signal_ax = plot_signal(t_s, s, xmin=0, xmax=0.05)

# %%
tau_s, varphi_ss = acf_time(t_s, s, 0.05)

# %%
#Plotting the autocorrelation function

acf_fig, acf_ax = plot_acf(tau_s, varphi_ss)

# %%
#Estimating the power density spectrum

f_s, PHI_ss = pds_time(t_s, s)
pds_fig, pds_ax = plot_pds(f_s, PHI_ss)

# %%
from thkdsp.audio import play_signal

# %%
play_signal(t_s, s)

# %% [markdown]
# Moving average of white noise

# %%
t_d, d = gen_dirac(0.001, 48000)

# %%
#Generating the impulse response 

t_h, h = moving_average(t_d, d, 1.0/4800.0)

# %%
#Plotting the impulse response h(t)

plot_signal(t_h, h, ylabel="h")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f5ac3490>)

# %%
#Generating a sample function of the output process

t_g, g = moving_average(t_s, s, 1.0/4800.0)

# %%
#Plot the white noise input process and the filtered noise output process to one figure

signal_fig, signal_ax = plot_signal(t_s, s, xmin=0, xmax=0.05, plotaxes=False)
plot_signal(t_g, g, xmax=0.05, figure=signal_fig, axes=signal_ax, color="r")
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %%
signal_fig, signal_ax = plot_signal(t_s, s, xmin=0.01, xmax=0.015, plotaxes=False)
plot_signal(t_g, g, xmin=0.01, xmax=0.015, figure=signal_fig, axes=signal_ax,color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f5a896d0>)

# %%
#Estimating the autocorrelation function

tau_g, varphi_gg = acf_time(t_g, g, 0.001)

# %%
#Plotting the autocorrelation funtion

plot_acf(tau_g, varphi_gg, xmin=-0.001, xmax=0.001)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f70c0ee0>)

# %%
#Estimating the power density spectrum of the output process

f_g, PHI_gg = pds_time(t_g, g)

#Plotting the power density spectrum

pds_fig, pds_ax = plot_pds(f_s, PHI_ss)
plot_pds(f_g, PHI_gg, figure=pds_fig, axes=pds_ax, color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f44eebb0>)

# %%
play_signal(t_g, g)

# %%
t_ma = t_g

# %%
g_ma = g

# %%
#Lab 7: Ideal lowpass with discrete-time white noise input

t_d, d = gen_dirac(0.01, 48000)

# %%
#Generating the impulse response by applying the impulse to the input of the ideal lowpass filter and measuring the output signal.

t_h, h = low_pass(t_d, d, 4800)

# %%
#Plotting the impulse response h(t)

plot_signal(t_h, h)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f3db8070>)

# %%
#Generating a sample function of the output process
t_g, g = low_pass(t_s, s, 4800)


#Plotting the white noise input process and the filtered noise output process to one figure and adding a legend:
signal_fig, signal_ax = plot_signal(t_s, s, xmin=0, xmax=0.05, plotaxes=False)
plot_signal(t_g, g, xmax=0.05, figure=signal_fig, axes=signal_ax, color="r")
leg = signal_ax.legend(('s(t)', 'g(t)'))

# %%
#To be able to spot a second less obvious difference

signal_fig, signal_ax = plot_signal(t_s, s, xmin=0.01, xmax=0.015, plotaxes=False)
plot_signal(t_g, g, xmin=0.01, xmax=0.015, figure=signal_fig, axes=signal_ax,color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f44814c0>)

# %%
#Estimating the autocorrelation function

tau_g, varphi_gg = acf_time(t_g, g, 0.001)

# %%
#Plotting the autocorrelation function

plot_acf(tau_g, varphi_gg, xmin=-0.001, xmax=0.001)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f40e23a0>)

# %%
#Estimating the power density spectrum

f_g, PHI_gg = pds_time(t_g, g)

# %%
#Plotting the power density spectrum

pds_fig, pds_ax = plot_pds(f_s, PHI_ss)
plot_pds(f_g, PHI_gg, figure=pds_fig, axes=pds_ax, color="r")
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2c6f3db7b80>)

# %%
play_signal(t_g, g)

# %%
#White noise:
play_signal(t_s, s)

# %%
#Moving average:
play_signal(t_ma, g_ma)

# %%
#Ideal lowpass:
play_signal(t_g, g)

# %% [markdown]
# ### When you run the command in the next code cell, the lab/homework will be finished!
# ### Execute the next code cell only if you really want to finish this lab/homework!
# ### This code cell should be your last code cell!

# %%
# finish homework
dsp_lab2_finish()
# Out:
# You are about to finish Lab 2: Stochastic Processes !
# This will finish output to the log file, such that you should not enter any command after finishing!
#
# Thus, proceed only if you are sure that you are really finished!!
# Do you really want to finish? yes/no: 11143654
# Please enter "yes" or "no"!
# Do you really want to finish? yes/no: yes
# Finishing Lab 2: Stochastic Processes for matriculation number 11143654
# Lab 2: Stochastic Processes  finished at: 2021-02-04 15:15:33.300343
# Finished after: 0:17:36.436160
# Info:  5400436791
# Congratulations! You have just finished Lab 2: Stochastic Processes !
#
# In your current working directory you will find the following Log file:
#
# Log file:  dsp_lab2_11143654.log
#
# Please save this iPython notebook one more time!
#
# Please upload both files to the ILIAS server:
# If this is a homework, use the 'Homework' folder of the ILIAS DSP internet pages!
# If this is a lab, use the 'Lab' folder of the ILIAS DSP internet pages!
#
# In either case you will be notified on the status of your submission via email.
#
# So stay tuned!
# Harald Elders-Boll

# %% [markdown]
# ### Please save this notebook one more time!
